# %%
# Initialize Otter
import otter
grader = otter.Notebook("Final.ipynb")

# %%
import numpy as np
from scipy.linalg import eig

# %% [markdown]
# ## Note
#
# Be sure to test the functions you define to make sure that they return what you expect.  This will help you to catch "silly" mistakes, like syntax errors or accidentally using ^ instead of ** for powers, misplaced parentheses etc.  We will try to catch some common problems with the grader, but we may not think of every possible mistake in advance.  **Check your functions like you would check your units!**

# %% [markdown]
# # Final exam

# %% [markdown]
# ### Q1
#
# Consider a combination of two problems that we did in lectures.  Imagine we have an "Atwood machine" consisting of two masses, $m_1$ and $m_2$, connected by a massless cord that loops over the top of a massless, frictionless pulley.  Let the left mass, $m_1$, hang a distance $q$ below the center of the pulley (which we shall take to be our origin and the zero of the gravitational potential) and the right mass, $m_2$, hang $\ell-q$ below the pulley center (as in lecture, but there we used $x$ not $q$).
#
# Further imagine that a mass $M$ is suspended below $m_1$ from a massless but rigid rod of length $L$, such that it can oscillate back and forth in the plane like a pendulum. Let its angle to the vertical be $\theta$, with $\theta$ increasing in the usual trigonometric sense (i.e. as the mass $M$ moves to the right, $\theta$ increases).
#
# We will take $m_1+M<m_2$ amd we will use Lagrangian mechanics to derive the equations of motion for $\theta$, in the limit $|\theta|\ll 1$.

# %% [markdown]
# (1.1) Write down the Lagrangian for just the Atwood part of the problem, i.e. without the pendulum of mass $M$ hanging below $m_1$.  Check carefully to ensure you have the sign of the potential correct, recalling that $q$ increases as the left-hand mass ($m_1$) falls.  You should drop any terms in the Lagrangian that are independent of both $q$ and $\dot{q}$. (5 pnt)

# %%
# Write a function that returns the "Atwood Lagrangian" given the
# masses m1, m2, the gravitational acceleration, g, the length ell
# and the position and velocity q and qdot defined in the problem.
def Atwood_L(m1,m2,g,ell,q,qdot):
    T = ...
    V = ...
    L = ...
    return(L)

# %% [markdown]
# (1.2) Now write down the "pendulum" part of the Lagrangian, in the small angle limit.  This Lagrangian should only depend upon $g$, $M$, $L$, $q$, $\dot{q}$ and $\theta$ and $\dot{\theta}$.  It should only include contributions from the kinetic and potential energy of the mass $M$.  There should be no terms higher than quadratic in $\theta$ and $\dot{\theta}$ and the Lagrangian should vanish when $q=\dot{q}=\theta=\dot{\theta}=0$.
#
# You should check that your Lagrangian has the right behavior when the pendulum is not swinging ($\dot{\theta}=0$) or if $m_1$ is stationary ($\dot{q}=0$) and any other limits that you can think of.  (5 pnt)

# %%
# Write a function that returns the "Pendulum Lagrangian".
def Pendulum_L(M,g,L,q,qdot,theta,theta_dot):

# %% [markdown]
# (1.3) Write out the equations of motion for $q$ and $\theta$, keeping only terms linear in $\theta$ or $\dot{\theta}$.
#
# Use your equations of motion to find $\ddot{q}$.
#
# Be careful of your signs -- if the left-hand mass ($m_1$) is accelerating downwards then $\ddot{q}$ will be positive!  (10 pnt)

# %%
# Return the acceleration of m1, \ddot{q}, given
# M, m1, m2 and g.
def qddot(M,m1,m2,g):
    ans = ...
    return(ans)

# %% [markdown]
# (1.4) What is the angular frequency, $\omega$, of the pendulum in terms of $L$, $g$ and $\ddot{q}$?  Be careful of your signs.  (10 pnt)

# %%
# Return the angular frequency, omega, of the pendulum
# in terms of L, g and \ddot{q}=qddot.
def pendulum_omega(L,g,qddot):
    ans = ...
    return(ans)

# %% [markdown]
# ### Q2
#
# Consider two massless rods, length $\ell$, hanging down from the two ends of a fixed horizontal bar of length $L$.  Each rod has a mass $m$ attached to its lower end and the masses are connected by a spring of constant $k$ with rest length $L$ so that the spring is unstretched when the rods hang vertically.
#
# Define $\theta_1$ and $\theta_2$ to be the angles of the rods from the vertical, with $\theta_i$ increasing outward (i.e. $\theta_1$ increases as the left mass moves left and $\theta_2$ increases as the right mass moves right).
#
# (2.1) Find the tensor $T_{ij}$ that defines the kinetic energy:
# $$
#   \mathrm{Kinetic\ energy} = \frac{1}{2} \sum_{i,j=1}^2 \dot{\theta}_i T_{ij} \dot{\theta}_j
# $$
# for small oscillations in this system about $\theta_i=0$.  (5 pnt)

# %%
# Write a function that returns Tij, given m, ell and L.
# Your return value should be a numpy array, so for example:
# np.array( [ [T_11,T_12],[T_21,T_22] ] )
# with the appropriate values of T_ij in each entry.
def Tij(m,ell,L):

# %% [markdown]
# (2.2) Find the tensor $V_{ij}$ that defines the potential energy:
# $$
#   \mathrm{Potential\ energy} = \frac{1}{2} \sum_{i,j=1}^2 \theta_i V_{ij} \theta_j
# $$
# for small oscillations in this system about $\theta_i=0$.  (5 pnt)

# %%
# Write a function that returns Vij given m, g, k, ell and L.
# As for the previous question, your answer should be a numpy array.
def Vij(m,g,k,ell,L):

# %% [markdown]
# (2.3) Using the input ```scipy.linalg``` function ```eig``` compute the normal mode frequencies. (10 pnt)
#
# **Hint**: you are asked for the normal mode frequencies, i.e. $\omega$, and not $\omega^2$.  These frequencies should be **real numbers**.  You can get the real part of a complex number in Python by using ```.real```, e.g. ```r=c.real```

# %%
# Write a function that returns a vector of the
# normal mode frequencies given Tij and Vij.
# Your answer should be a numpy array containing two real numbers,
# for the two values of omega (NOT omega^2).
def omega(Tij,Vij):

# %% [markdown]
# (2.4) Imagine that the spring is taken to be very stiff, i.e. $k\to\infty$.
# Being careful to remember the definition of the $\theta_i$, write a function that returns $(\theta_1(t),\theta_2(t))$, i.e. a ```numpy``` array of length 2, if the initial conditions are $\theta_1(0)=1$, $\theta_2(0)=-1$, $\dot{\theta}_1(0)=\dot{\theta}_2(0)=0$. (10 pnt)
#
# Hint: you can do this numerically if you wish, however thinking through this limit may lead you to a simpler solution.  Also, be careful of the signs of the $\theta_i$.  In our convention if the two rods move in the same direction the $\theta$s should have different signs.

# %%
# Write a function that returns a 2D numpy array containing
# theta_1(t) and theta_2(t) given m,g,k,ell,L and t.
# Be careful of the definition of the signs of theta_i.
def thetas(m,g,k,ell,L,t):

# %% [markdown]
# ### Q3
#
# Consider a (relativistic) particle of charge $q$ and mass $m$ in the presence of a (positive) unit charge fixed at the origin of coordinates.  This positive unit charge at the origin is immobile and does not take part in our dynamics at all.
#
# There are no forces aside from the Coulomb force between the charges and we shall choose our units such that $4\pi\epsilon_0=1$ and $c=1$ for this question.  Thus, for example, the rest-mass energy will be simply $m$ (not $mc^2$) and the Coulomb potential between charges $Q_1$ and $Q_2$ would be $Q_1Q_2/r$.

# %% [markdown]
# (3.1) What is the total energy, $E$, of the **first** (relativistic) particle, in canonical, polar coordinates?  This should include the rest-mass energy of the particle.  Specifically, writing $\vec{p}$ in polar coordinates ($p_r$, $p_\theta$ and $p_\phi$) and denoting the conserved angular momentum as $\ell$ what is $E$?
#
# (10 pnt)

# %%
# Return the (total) energy of the particle of mass m
# in terms of m, q, pr, ell and r.
def total_energy(m,q,pr,ell,r):
    ans = ...
    return(ans)

# %% [markdown]
# (3.2) If $q<0$, what is the value of $\ell$ that allows the particles to approach arbitrarily close to each other?
#
# You may assume $\ell>0$, i.e. your answer should be positive.
# You should use an expression, rather than attempting a numerical solution.
# (10 pnt)

# %%
# What is ell given m, q and pr?
def ell_val(m,q,pr):
    ans = ...
    return(ans)

# %% [markdown]
# (3.3) Now let us change the problem so that rather than the positive unit charge being fixed at the origin, it has the same mass as the charge $q$ (i.e. $m$).  Specifically, let us consider *positronium* where one particle is an electron (of charge $-e$) and the other is a positron (of charge $+e$) both of equal mass: $m_e$.
#
# If the orbit is circular and the binding energy is $-0.01m_e$ (remember $c=1$) how fast are they each moving in the center of mass frame?
#
# [Hint: note that $0.01$ is not very big, compared so e.g. 1.  Also, the binding energy equals the total energy minus the contribution from the rest mass, thus it is negative.]
# (10 pnt)

# %%
# Return the velocity of either particle (electron or positron).
# Remember c=1, so this velocity is in units of the speed of light.
def particle_velocity():
    ans = ...
    return(ans)

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit.
#
# Upload the .ipynb or .zip file to Gradescope!

# %%
grader.export(pdf=False, force_save=True, run_tests=True)
